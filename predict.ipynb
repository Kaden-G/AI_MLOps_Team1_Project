# %%
import requests
from skimage import io
import json

# %%
body = {
    "model_path": "/home/user/jhu/mlops/AI_MLOps_Team1_Project/models/nn_1",
    "model_type": "nn"
}

requests.post("http://127.0.0.1:8000/load_model", json=body).text
# Out:
# '"Successful"'

# %%
body = {
    "image": io.imread("/home/user/jhu/mlops/AI_MLOps_Team1_Project/data/initial/Brain Tumor/Brain Tumor/Image1.jpg").tolist()
}

response = requests.post("http://127.0.0.1:8000/predict", json=body)
response.text
# Out:
# '"No tumor detected"'

# %%
# Out:
# <Response [500]>
